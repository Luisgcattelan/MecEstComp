# %%
import numpy as np
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set()
plt.rcParams["figure.figsize"] = (16,9)

# %%
n_flips = 5 # Number of spin flips
data = stats.randint.rvs(0, 2, size=n_flips)

# %%
def bins_labels(bins, **kwargs):
    bin_w = (max(bins) - min(bins)) / (len(bins) - 1)
    plt.xticks(np.arange(min(bins)+bin_w/2, max(bins), bin_w), bins, **kwargs)
    plt.xlim(bins[0], bins[-1])

# %%
n_expts = 10000   
results = np.zeros(n_expts) # Create array for results of "experiments"

for i in range(n_expts):
    results[i] = np.sum(stats.randint.rvs(0, 2, size=n_flips))

bins = range(n_expts+1)
freq = results/n_expts
plt.hist(results, bins=bins, density=True)
plt.xlabel("# of heads")
plt.ylabel("occurrences")
plt.xlim(0, 6)
plt.show()

# %%
bins = range(7)
plt.hist(results, bins=bins, density=True, label='Medida')
plt.xlabel("N° de caras")
plt.ylabel("Probabilidade")
plt.xlim(0, 6)
plt.title('Distruibuição de caras em 10000 histórias')
bins_labels(bins, fontsize=10)
plt.plot(x+ 0.5, g, label='Gaussiana')
plt.legend()
plt.show()

# %%
p=0.5
n=5
x= np.linspace(0,6)
sig2 = n*p*(1-p)
g = 1/np.sqrt(2*np.pi*sig2) * np.exp(-(x-n*p)**2/2/sig2 )

plt.plot(x, g)
